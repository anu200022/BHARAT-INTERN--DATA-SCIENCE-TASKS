# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Google Stocks.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 6s 78ms/step - loss: 0.0088 - mean_absolute_error: 0.0647 - val_loss: 0.0225 - val_mean_absolute_error: 0.1277
# Epoch 2/100
# 28/28 [==============================] - 2s 65ms/step - loss: 8.3416e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0041 - val_mean_absolute_error: 0.0478
# Epoch 3/100
# 28/28 [==============================] - 2s 67ms/step - loss: 4.5821e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0024 - val_mean_absolute_error: 0.0375
# Epoch 4/100
# 28/28 [==============================] - 2s 63ms/step - loss: 4.3609e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0037 - val_mean_absolute_error: 0.0468
# Epoch 5/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.0118e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0041 - val_mean_absolute_error: 0.0496
# Epoch 6/100
# 28/28 [==============================] - 1s 51ms/step - loss: 4.1555e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0035 - val_mean_absolute_error: 0.0451
# Epoch 7/100
# 28/28 [==============================] - 2s 63ms/step - loss: 4.0277e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0045 - val_mean_absolute_error: 0.0520
# Epoch 8/100
# 28/28 [==============================] - 2s 56ms/step - loss: 4.0000e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0051 - val_mean_absolute_error: 0.0555
# Epoch 9/100
# 28/28 [==============================] - 2s 64ms/step - loss: 4.0521e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0046 - val_mean_absolute_error: 0.0528
# Epoch 10/100
# 28/28 [==============================] - 2s 60ms/step - loss: 4.1478e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0044 - val_mean_absolute_error: 0.0510
# Epoch 11/100
# 28/28 [==============================] - 1s 50ms/step - loss: 3.7755e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0065 - val_mean_absolute_error: 0.0650
# Epoch 12/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.6506e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0070 - val_mean_absolute_error: 0.0673
# Epoch 13/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.6036e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0058 - val_mean_absolute_error: 0.0601
# Epoch 14/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.7787e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0048 - val_mean_absolute_error: 0.0538
# Epoch 15/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.5707e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0054 - val_mean_absolute_error: 0.0576
# Epoch 16/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.3071e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0053 - val_mean_absolute_error: 0.0563
# Epoch 17/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.3038e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0057 - val_mean_absolute_error: 0.0591
# Epoch 18/100
# 28/28 [==============================] - 2s 59ms/step - loss: 3.0511e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0070 - val_mean_absolute_error: 0.0657
# Epoch 19/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.9132e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0050 - val_mean_absolute_error: 0.0542
# Epoch 20/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.0430e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0074 - val_mean_absolute_error: 0.0672
# Epoch 21/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.8320e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0081 - val_mean_absolute_error: 0.0723
# Epoch 22/100
# 28/28 [==============================] - 2s 64ms/step - loss: 3.2190e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 23/100
# 28/28 [==============================] - 2s 65ms/step - loss: 3.0874e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0043 - val_mean_absolute_error: 0.0500
# Epoch 24/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.7661e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0083 - val_mean_absolute_error: 0.0737
# Epoch 25/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.9537e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0081 - val_mean_absolute_error: 0.0708
# Epoch 26/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.7808e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0058 - val_mean_absolute_error: 0.0568
# Epoch 27/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.6263e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0068 - val_mean_absolute_error: 0.0643
# Epoch 28/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.5870e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0041 - val_mean_absolute_error: 0.0467
# Epoch 29/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.5876e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0054 - val_mean_absolute_error: 0.0552
# Epoch 30/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.7109e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0066 - val_mean_absolute_error: 0.0628
# Epoch 31/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.7732e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0105 - val_mean_absolute_error: 0.0840
# Epoch 32/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.6578e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0059 - val_mean_absolute_error: 0.0598
# Epoch 33/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.2629e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0061 - val_mean_absolute_error: 0.0596
# Epoch 34/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.5595e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0087 - val_mean_absolute_error: 0.0757
# Epoch 35/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.6547e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0062 - val_mean_absolute_error: 0.0609
# Epoch 36/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.3093e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0067 - val_mean_absolute_error: 0.0636
# Epoch 37/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.4322e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0043 - val_mean_absolute_error: 0.0488
# Epoch 38/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.1805e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0042 - val_mean_absolute_error: 0.0476
# Epoch 39/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.3811e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0072 - val_mean_absolute_error: 0.0675
# Epoch 40/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.1546e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0040 - val_mean_absolute_error: 0.0461
# Epoch 41/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.1848e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0069 - val_mean_absolute_error: 0.0664
# Epoch 42/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.0947e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0033 - val_mean_absolute_error: 0.0411
# Epoch 43/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.0691e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0051 - val_mean_absolute_error: 0.0562
# Epoch 44/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.3516e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0070 - val_mean_absolute_error: 0.0679
# Epoch 45/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1457e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0040 - val_mean_absolute_error: 0.0485
# Epoch 46/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.0668e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0034 - val_mean_absolute_error: 0.0434
# Epoch 47/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.0004e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0036 - val_mean_absolute_error: 0.0448
# Epoch 48/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.0702e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0054 - val_mean_absolute_error: 0.0584
# Epoch 49/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.0017e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 50/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.8570e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0044 - val_mean_absolute_error: 0.0501
# Epoch 51/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.8964e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0023 - val_mean_absolute_error: 0.0336
# Epoch 52/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.0174e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0041 - val_mean_absolute_error: 0.0498
# Epoch 53/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.9401e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0027 - val_mean_absolute_error: 0.0381
# Epoch 54/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.8544e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0019 - val_mean_absolute_error: 0.0310
# Epoch 55/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.8567e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0021 - val_mean_absolute_error: 0.0324
# Epoch 56/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.8453e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0034 - val_mean_absolute_error: 0.0439
# Epoch 57/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.7034e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0040 - val_mean_absolute_error: 0.0469
# Epoch 58/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.7055e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0071 - val_mean_absolute_error: 0.0674
# Epoch 59/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.6152e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0037 - val_mean_absolute_error: 0.0450
# Epoch 60/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.5202e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0030 - val_mean_absolute_error: 0.0407
# Epoch 61/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.8923e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0028 - val_mean_absolute_error: 0.0405
# Epoch 62/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.5683e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0026 - val_mean_absolute_error: 0.0397
# Epoch 63/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.7348e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0031 - val_mean_absolute_error: 0.0436
# Epoch 64/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.7653e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0036 - val_mean_absolute_error: 0.0465
# Epoch 65/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.5474e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0025 - val_mean_absolute_error: 0.0372
# Epoch 66/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.5565e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0028 - val_mean_absolute_error: 0.0406
# Epoch 67/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.5143e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0039 - val_mean_absolute_error: 0.0492
# Epoch 68/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.7169e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0050 - val_mean_absolute_error: 0.0581
# Epoch 69/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.7890e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0025 - val_mean_absolute_error: 0.0376
# Epoch 70/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.3962e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0018 - val_mean_absolute_error: 0.0311
# Epoch 71/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.3656e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351
# Epoch 72/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.3309e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0015 - val_mean_absolute_error: 0.0277
# Epoch 73/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.4673e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0025 - val_mean_absolute_error: 0.0380
# Epoch 74/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.4645e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0025 - val_mean_absolute_error: 0.0378
# Epoch 75/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.4006e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0037 - val_mean_absolute_error: 0.0486
# Epoch 76/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.6389e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0028 - val_mean_absolute_error: 0.0422
# Epoch 77/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.3871e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0030 - val_mean_absolute_error: 0.0435
# Epoch 78/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2138e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0019 - val_mean_absolute_error: 0.0313
# Epoch 79/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.2579e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268
# Epoch 80/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2491e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 81/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.3331e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0030 - val_mean_absolute_error: 0.0437
# Epoch 82/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.1827e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0016 - val_mean_absolute_error: 0.0293
# Epoch 83/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.2772e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0026 - val_mean_absolute_error: 0.0405
# Epoch 84/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.2672e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 85/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.1313e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0022 - val_mean_absolute_error: 0.0359
# Epoch 86/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.1595e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0023 - val_mean_absolute_error: 0.0366
# Epoch 87/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1479e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0020 - val_mean_absolute_error: 0.0334
# Epoch 88/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.0700e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
# Epoch 89/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.1605e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0029 - val_mean_absolute_error: 0.0426
# Epoch 90/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.1845e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0019 - val_mean_absolute_error: 0.0322
# Epoch 91/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.0822e-04 - mean_absolute_error: 0.0074 - val_loss: 9.0667e-04 - val_mean_absolute_error: 0.0215
# Epoch 92/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.1795e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0021 - val_mean_absolute_error: 0.0343
# Epoch 93/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.2370e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0020 - val_mean_absolute_error: 0.0351
# Epoch 94/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1195e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0017 - val_mean_absolute_error: 0.0313
# Epoch 95/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0016 - val_mean_absolute_error: 0.0302
# Epoch 96/100
# 28/28 [==============================] - 2s 63ms/step - loss: 9.8467e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
# Epoch 97/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1097e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0018 - val_mean_absolute_error: 0.0323
# Epoch 98/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.0823e-04 - mean_absolute_error: 0.0074 - val_loss: 7.8415e-04 - val_mean_absolute_error: 0.0201
# Epoch 99/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0143e-04 - mean_absolute_error: 0.0071 - val_loss: 5.3019e-04 - val_mean_absolute_error: 0.0163
# Epoch 100/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.1203e-04 - mean_absolute_error: 0.0076 - val_loss: 8.5162e-04 - val_mean_absolute_error: 0.0201

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# array([[0.40445665, 0.39999565],
#        [0.40456703, 0.40021876],
#        [0.40232238, 0.39793786],
#        [0.4072637 , 0.40230682],
#        [0.41116807, 0.40604115]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1420.8302, 1409.5879],
#        [1421.0349, 1410.0015],
#        [1416.8734, 1405.7742],
#        [1426.0343, 1413.8713],
#        [1433.2727, 1420.7924]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1420.830200      1409.587891
# 2020-05-28  1396.86  1416.73     1421.034912      1410.001465
# 2020-05-29  1416.94  1428.92     1416.873413      1405.774170
# 2020-06-01  1418.39  1431.82     1426.034302      1413.871338
# 2020-06-02  1430.55  1439.22     1433.272705      1420.792358

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2459.406982      2343.117188
# 2021-06-10  2494.01  2521.60     2463.884277      2346.003418
# 2021-06-11  2524.92  2513.93     2488.708740      2366.118408
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
